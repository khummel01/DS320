# %%
# %matplotlib inline
import pandas as pd
import matplotlib
import requests
from bs4 import BeautifulSoup
import re

# %% [markdown]
# ### practice

# %%
mainPage = requests.get("https://www.luther.edu/catalog/curriculum/")

# %%
soup = BeautifulSoup(mainPage.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" id="luther-edu" lang="en">
#  <head>
#   <script src="/jquery/jquery-1.11.2.min.js" type="text/javascript">
#   </script>
#   <title>
#    Curriculum | 2017–18 Academic Catalog | Luther College
#   </title>
#   <link href="/reason/css/twitter/twitter.css" rel="stylesheet" type="text/css"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <script type="text/javascript">
# ...

# %%
dept_list = soup.select('ul.childrenList a')
dept_list
# for dept in dept_list:
#     print(dept.get('href','None'))
# Out:
# [<a name="child_A"></a>,
#  <a href="accounting/">Accounting</a>,
#  <a href="africana-studies/">Africana Studies</a>,
#  <a href="anthropology/">Anthropology</a>,
#  <a href="art/">Art</a>,
#  <a href="art-history/">Art History</a>,
#  <a href="asian-studies/">Asian Studies</a>,
#  <a href="athletic-training/">Athletic Training</a>,
#  <a name="child_B"></a>,
#  <a href="biblical-languages/">Biblical Languages</a>,
#  <a href="biology/">Biology</a>,
#  <a name="child_C"></a>,
#  <a href="chemistry/">Chemistry</a>,
#  <a href="chinese/">Chinese</a>,
#  <a href="classics/">Classics</a>,
#  <a href="communication-studies/">Communication Studies</a>,
#  <a href="computer-science/">Computer Science</a>,
#  <a name="child_D"></a>,
#  <a href="dance/">Dance</a>,
#  <a href="data-science/">Data Science</a>,
#  <a name="child_E"></a>,
#  <a href="economics/">Economics</a>,
#  <a href="english/">English</a>,
#  <a href="education/">Education</a>,
# ...

# %%
play = {'major':['Computer Science','Accounting'],
        'course_title':['Intro to CS','Intro to Accounting'],
        'course_num':['CS150','ACCT135'],
        'hours':[4,4],
        'geneds':['quant','quant'],
        'prereqs':['none','none'],
        'description':['learn python!','learning accouting stuff!']}

# %%
df = pd.DataFrame(play,columns=['major','course_title','course_num','hours','geneds','prereqs','description'])
df
# Out:
#               major         course_title course_num  hours geneds prereqs  \
# 0  Computer Science          Intro to CS      CS150      4  quant    none
# 1        Accounting  Intro to Accounting    ACCT135      4  quant    none
#
#                  description
# 0              learn python!
# 1  learning accouting stuff!

# %%
dept_list = soup.select('ul.childrenList a')

# %%
url = requests.get('http://www.luther.edu/catalog/curriculum/computer-science')
sup = BeautifulSoup(url.text, 'html.parser')
# for e in sup.find_all('span',class_='genEd'):
#     print(e.text)
# print('---------')
# master = []
# geneds = []
# whereiam = 0
# for a in sup.find_all('span',class_='genEd'):
#     geneds.append(a.text)
for x in sup.select('ul.fa-ul'):
    print(x.text)
    if 'Fulfills:' in x.text: 
        master.append(geneds[whereiam])
        whereiam += 1
    else:
        master.append('None')
        whereiam += 1
# print(master)
# Out:
# 2, 4 hours
#
#
# 2 hours
#
#
# 4 hours
# Fulfills: Quantitative
#
#
# 4 hours
# Prerequisites: CS 150
#
#
# 2 hours
#
#
# 2 hours
# Prerequisites: CS 150 and CS 165
#
#
# 2 hours
# Prerequisites: CS 150 and CS 165
#
#
# 4 hours
# Prerequisites: CS 160 and CS 165
#
#
# 1 hour
#
#
# 4 hours
# Prerequisites: CS 150 and MATH 115 or the equivalent
#
#
# 4 hours
# Prerequisites: CS 130, CS 140 and CS 160
#
#
# 4 hours
# Prerequisites: CS 200 or CS 253
#
#
# 4 hours
# Prerequisites: CS 253
#
#
# 4 hours
#
#
# 4 hours
# Prerequisites: CS 252 or 253 and 260
#
#
# 4 hours
# Prerequisites: Junior standing
#
#
# 4 hours
# Prerequisites: CS 260 and 320
#
#
# 4 hours
# Prerequisites: CS 252 or 253 and 260
#
#
# 4 hours
# Prerequisites: CS 140, 252 or 253 and 260
#
#
# 4 hours
# Prerequisites: CS 252 or 253 and 260
#
#
# 2 hours
#
#
# 2 hours
# Prerequisites: CS 490

# %%
play= {'major':[],
        'course_title':[],
        'course_num':[],
        'hours':[],
        'geneds':[],
        'prereqs':[],
        'description':[]}

h = major.get('href','None')
for title in sup.find_all('span', class_='courseTitle'):
    play['course_title'].append(title.text)
    play['major'].append(majorName)
for num in sup.find_all('span', class_='courseNumber'):
    play['course_num'].append(num.text)
for courseDescription in sup.find_all('span', class_='courseDescription'):
    play['description'].append(courseDescription.text)
for genEd in sup.find_all('span', class_='genEd'):
    play['geneds'].append(genEd.text)
for courseHrs in sup.select('ul.fa-ul'):
    a = str(courseHrs)
    b = re.findall('\d+\shours',a)
    c = ''.join(b)
    courseDict['hours'].append(c)
    
    
    
    
#             a = re.findall('\d+\shours',courseHrs.text[1])
#         hrs = a.pop()
#         coursesDict['hours'].append(hrs)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-243-b6642f69a0a0> in <module>()
#      21     b = re.findall('\d+\shours',a)
#      22     c = ''.join(b)
# ---> 23     courseHrs['hours'].append(c)
#      24
#      25
#
# /usr/local/lib/python3.5/site-packages/bs4/element.py in __getitem__(self, key)
#    1009         """tag[key] returns the value of the 'key' attribute for the tag,
#    1010         and throws an exception if it's not there."""
# -> 1011         return self.attrs[key]
#    1012
#    1013     def __iter__(self):
#
# KeyError: 'hours'

# %%
play
# Out:
# {'course_num': ['CS 130',
#   'CS 140',
#   'CS 150',
#   'CS 160',
#   'CS 165',
#   'CS 252',
#   'CS 253',
#   'CS 260',
#   'CS 296',
#   'CS 320',
#   'CS 330',
#   'CS 352',
#   'CS 353',
#   'CS 360',
#   'CS 370',
#   'CS 385',
#   'CS 420',
#   'CS 430',
#   'CS 440',
#   'CS 450',
#   'CS 490',
#   'CS 491'],
#  'course_title': ['Fundamentals of Web Programming',
#   'Data Modeling and Querying',
#   'Introduction to Computer Science',
#   'Algorithms and Data Structures',
#   'Software Development Tools',
#   'Object-Oriented Programming With Java',
#   'Object-Oriented Programming With C++',
#   'Computational Models',
#   'Writing in the Major Lab',
#   'Data Analysis and Visualization',
#   'Internet Programming',
#   'Embedded Android Programming',
#   'Embedded iOS Programming',
#   'Advanced Algorithms and Data Structures',
#   'Programming Languages',
#   'Understanding Entrepreneurship in Silicon Valley',
#   'Machine Learning',
#   'Computer Networks',
# ...

# %% [markdown]
# ### real

# %%
coursesDict = {'major':[],
        'course_title':[],
        'course_num':[],
        'hours':[],
        'geneds':[],
        'prereqs':[],
        'description':[]}

for major in dept_list:
    majorName = major.get('href','None')
    page = requests.get("http://www.luther.edu/catalog/curriculum/{}".format(majorName))
    soup = BeautifulSoup(page.text, 'html.parser')   
    
    for title in soup.find_all('span', class_='courseTitle'):
        coursesDict['course_title'].append(title.text)
        coursesDict['major'].append(majorName)
    for num in soup.find_all('span', class_='courseNumber'):
        coursesDict['course_num'].append(num.text)
    for courseDescription in soup.find_all('span', class_='courseDescription'):
        coursesDict['description'].append(courseDescription.text)
    for courseHrs in soup.select('ul.fa-ul'):
        coursesDict['hours'].append(courseHrs.text[1])

    fulfills = []
    fulfills_count = 0
    for e in soup.find_all('span',class_='genEd'):
        e = e.text
        fulfills.append(e)
    for x in soup.select('ul.fa-ul'):
        if "Fulfills:" not in x.text:
            coursesDict['geneds'].append('None')
        else:
            coursesDict['geneds'].append(fulfills[fulfills_count])
            fulfills_count += 1
            
    for x in soup.select('ul.fa-ul'):
        if "Prerequisites" in x.text:
            x= x.text
            x = x[23:]
            coursesDict['prereqs'].append(x)
        else:
            coursesDict['prereqs'].append('None')

# %%
coursesDict
# Out:
# {'course_num': ['ACCTG 110',
#   'ACCTG 150',
#   'ACCTG 250',
#   'ACCTG 353',
#   'ACCTG 354',
#   'ACCTG 357',
#   'ACCTG 358',
#   'ACCTG 365',
#   'ACCTG 467',
#   'ACCTG 468',
#   'ACCTG 485',
#   'ACCTG 490',
#   'AFRS 135',
#   'AFRS 147',
#   'AFRS 171',
#   'AFRS 172',
#   'AFRS 221',
#   'AFRS 235',
#   'AFRS 240',
#   'AFRS 247',
#   'AFRS 251',
#   'AFRS 271',
#   'AFRS 331',
#   'AFRS 345',
#   'AFRS 371',
#   'AFRS 391',
#   'AFRS 485',
#   'AFRS 490',
#   'ANTH 101',
#   'ANTH 102',
#   'ANTH 103',
#   'ANTH 104',
#   'ANTH 203',
#   'ANTH 204',
#   'ANTH 205',
#   'ANTH 208',
#   'ANTH 209',
#   'ANTH 210',
#   'ANTH 211',
#   'ANTH 221',
#   'ANTH 264',
#   'ANTH 301',
#   'ANTH 302',
#   'ANTH 303',
#   'ANTH 306',
#   'ANTH 401',
#   'ANTH 490',
#   'ART 101',
#   'ART 103',
#   'ART 104',
#   'ART 105',
#   'ART 108',
#   'ART 111',
#   'ART 114',
#   'ART 115',
#   'ART 121',
#   'ART 200',
#   'ART 205',
#   'ART 206',
#   'ART 207',
#   'ART 208',
# ...

# %%
len(coursesDict['hours'])
# Out:
# 1650

# %%
courseDf = pd.DataFrame(coursesDict,columns=['major','course_title','course_num','hours','geneds','prereqs','description'])
courseDf
# Out:
#                      major                                       course_title  \
# 0              accounting/                         Introduction to Accounting
# 1              accounting/                         Fundamentals of Accounting
# 2              accounting/                       Managerial Cost Accounting I
# 3              accounting/                          Intermediate Accounting I
# 4              accounting/                         Intermediate Accounting II
# 5              accounting/   Accounting for Government and Nonprofit Entities
# 6              accounting/                      Managerial Cost Accounting II
# 7              accounting/                                Advanced Accounting
# 8              accounting/                    Auditing and Assurance Services
# 9              accounting/                            Federal Income Taxation
# 10             accounting/                                            Seminar
# ...

# %%
courseDf.to_csv('curriculum.csv',encoding='utf-8')
